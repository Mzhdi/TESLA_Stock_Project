# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import os

# %%
df=pd.read_csv(r'C:\Users\admin\Desktop\Course\TESLA_Stock\TSLA.csv')
df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
#Check Nan values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Get a general analysis on the Dataframe
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2416.000000  2416.000000  2416.000000  2416.000000  2416.000000
# mean    186.271147   189.578224   182.916639   186.403651   186.403651
# std     118.740163   120.892329   116.857591   119.136020   119.136020
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      34.342498    34.897501    33.587501    34.400002    34.400002
# 50%     213.035004   216.745002   208.870002   212.960007   212.960007
# 75%     266.450012   270.927513   262.102501   266.774994   266.774994
# max     673.690002   786.140015   673.520020   780.000000   780.000000
#
#              Volume
# count  2.416000e+03
# mean   5.572722e+06
# std    4.987809e+06
# min    1.185000e+05
# 25%    1.899275e+06
# 50%    4.578400e+06
# 75%    7.361150e+06
# max    4.706500e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416 entries, 0 to 2415
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2416 non-null   object
#  1   Open       2416 non-null   float64
#  2   High       2416 non-null   float64
#  3   Low        2416 non-null   float64
#  4   Close      2416 non-null   float64
#  5   Adj Close  2416 non-null   float64
#  6   Volume     2416 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 132.2+ KB

# %% [markdown]
# # Check the month with the most participation

# %%
df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
#Building functions to get the month & year 
def month(x):
    return x.split('-')[1]
month('2010-06-29')
# Out:
# '06'

# %%
def year(x):
  return x.split('-')[0]

year('2010-06-29')
# Out:
# '2010'

# %%
#Adding new columns YEAR & MONTH
df['year']=df['Date'].apply(year)
df['month']=df['Date'].apply(month)
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume  year month
# ...

# %%
#Then, We get the unique values of months in our dataset
df['month'].unique()
# Out:
# array(['06', '07', '08', '09', '10', '11', '12', '01', '02', '03', '04',
#        '05'], dtype=object)

# %%
#Also, We get the unique values of years in our dataset
df['year'].unique()
# Out:
# array(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020'], dtype=object)

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# year          object
# month         object
# dtype: object

# %%
import matplotlib.pyplot as plt
#Convert column to list
x = df['year'].to_list()
p = 0
l = []
for i in df['year'].unique():
    for j in x:
        if i == j :
            p +=1
    l += [p]
    p = 0 
q=0
t=[]
c = 0
for i in t:
    for j in range(c,c+i):
        q += df['Volume'].to_list()[j]
    t = t + [q/i]
    q = 0
    c = c +i
plt.show()
plt.bar(df['year'].unique(),t)
plt.figure(figsize=(24,20))

# %% [markdown]
# # Visualization of Average TESLA Stock Price each year

# %%
df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume  \
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900
#
#    year month
# 0  2010    06
# 1  2010    06
# 2  2010    07
# 3  2010    07
# 4  2010    07

# %%
#Plotting the "High" mean for each year
import matplotlib.pyplot as plt
x = df['year'].to_list()
a = 0
l = []
for i in df['year'].unique():
    for j in x:
        if i == j :
            a +=1
    l += [a]
    a = 0
#print(len(l)) 
b=0
r=[]
c = 0
for i in r:
    for j in range(c,c+i):
        b += df['High'].to_list()[j]
    r = r + [b/i]
    b = 0
    c = c +i    
plt.figure(figsize=(16;11))
plt.plot(df['year'].unique(),r,linewidth=4 )
plt.title("The High Average every year since 2010")
# Out:
# Text(0.5, 1.0, 'The High Average every year since 2010')

# %%
#Now we will plot the "Low" mean for each year
import matplotlib.pyplot as plt
x = df['year'].to_list()
s = 0
l = []
for i in df['year'].unique():
    for j in x:
        if i == j :
            s +=1
    l += [s]
    s = 0
#print(len(l)) 
m=0
t=[]
c = 0
for i in t:
    for j in range(c,c+i):
        m += df['Low'].to_list()[j]
    t = t + [m/i]
    m = 0
    c = c +i
plt.figure(figsize=(15,10))
plt.plot(df['year'].unique(),t,linewidth=1,color='black',label='Low')
plt.plot(df['year'].unique(),r,linewidth=1,color='red',label='High')
plt.legend(fontsize=15)
plt.title('Variation of High and Low in time')
# Out:
# Text(0.5, 1.0, 'Variation of High and Low in time')

# %% [markdown]
# # TESLA stock analysis for the last few years

# %%
df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume  \
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900
#
#    year month
# 0  2010    06
# 1  2010    06
# 2  2010    07
# 3  2010    07
# 4  2010    07

# %%
#Visualizing Volume and Date

plt.figure(figsize=(12,8))
plt.plot(df['Date'],df['Volume'])

# %%
#Comparing between plots of Date/Close & Date/Open
plt.figure(figsize=(12,8))
plt.plot(df['Date'],df['Open'],color='red',label='Open')
plt.plot(df['Date'],df['Close'],color='Black',label='Close')
plt.legend(fontsize=14)
plt.show()

# %%
#Comparison between plots of Date/High & Date/Low
plt.figure(figsize=(12,8))
plt.plot(df['Date'],df['High'],color='red',label='High')
plt.plot(df['Date'],df['Low'],color='Black',label='Low')
plt.legend(fontsize=14)
plt.show()

# %%
#Scatter plot of 2 Variables Month & Volume
plt.figure(figsize=(12,8))
plt.scatter(df['month'],df['Volume'], c ='red')
plt.show()

# %%
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
for i in range(len(df['Date'])):
    df['Date'][i] = i
df['Date']

X_train,X_test,Y_train,Y_test = train_test_split(df['Date'],df['Volume'])
X_train_df, Y_train_df =pd.DataFrame(X_train), pd.DataFrame(Y_train)


poly= PolynomialFeatures(degree = 2)
X_train_poly = poly.fit_transform(X_train_df) 

model = linear_model.LinearRegression()
model = model.fit(X_train_df, Y_train)
coefficient = model.coef_
intercept = model.intercept_
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_9500/2971538904.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'][i] = i

# %%
from sklearn.linear_model import LinearRegression
X = pd.DataFrame(df['Date'])
y = pd.DataFrame(df['Volume'])
X_forcast = X[:31].transform(lambda x: x + 504)
lin_reg=LinearRegression()
lin_reg.fit(X_train_df,Y_train_df)

poly_reg=PolynomialFeatures(degree=4)
X_poly=poly_reg.fit_transform(X)
poly_reg.fit(X_poly,y)

lin_reg.fit(X_poly,y)
X_grid=np.arange(0,534,0.1)
X_grid=X_grid.reshape((len(X_grid),1))

#Plot
plt.figure(figsize=(12,8))
plt.scatter(X_train, Y_train, c="b" , label = "training points")
plt.scatter(X_test, Y_test, c="g" , label = "testing points")
plt.plot(X,lin_reg.predict(poly_reg.fit_transform(X)),color='red',linewidth=4)
plt.plot(X_forcast,lin_reg.predict(poly_reg.fit_transform(X_forcast)),color='red',linewidth=4)
plt.show()

X_test_df, Y_test_df =pd.DataFrame(X_test), pd.DataFrame(Y_test)
print(model.score(X_test_df,Y_test_df))
# Out:
# 0.25101528520997907

# %%
from sklearn.svm import SVR 
model = SVR(C=1000000,degree=10,gamma='auto')

X_test_df, Y_test_df =pd.DataFrame(X_test), pd.DataFrame(Y_test)

model.fit(X_train_df,Y_train_df)
print(model.score(X_test_df,Y_test_df))
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.115743393178106
